# %%
import pandas as pd

# %%
# comando para ler o arquivo
data = pd.read_csv (filepath_or_buffer ='C:/Users/Gabriel-PC/Bootcamp-Data-science/teste/aulas/2023.05.31 - aula Nopha/dataframe_python.csv')

# %%
# mostra o dataframe
data
# Out:
#                                          role          fit  \
# 0       {'S': 'Analista de Recursos Humanos'}  {'N': '77'}
# 1        {'S': 'Diretor de Recursos Humanos'}  {'N': '51'}
# 2                  {'S': 'Diretor Executivo'}  {'N': '49'}
# 3        {'S': 'CEO Chief Executive Officer'}  {'N': '64'}
# 4            {'S': 'Auxiliar Administrativo'}  {'N': '70'}
# ...                                       ...          ...
# 1550            {'S': 'Analista de Sistemas'}   {'N': '0'}
# 1551  {'S': 'Coordenador de Desenvolvimento'}  {'N': '44'}
# 1552    {'S': 'Analista de Recursos Humanos'}  {'N': '74'}
# 1553     {'S': 'Gerente de Recursos Humanos'}  {'N': '44'}
# 1554    {'S': 'Analista de Recursos Humanos'}  {'N': '83'}
#
#                                    natural_percentage  \
# 0     {'S': '[{"F": 45, "L": 74, "O": 88, "W": 48}]'}
# 1     {'S': '[{"F": 88, "L": 22, "O": 44, "W": 64}]'}
# 2     {'S': '[{"F": 32, "L": 87, "O": 67, "W": 64}]'}
# 3     {'S': '[{"F": 88, "L": 45, "O": 52, "W": 48}]'}
# 4     {'S': '[{"F": 54, "L": 22, "O": 58, "W": 79}]'}
# ...                                               ...
# 1550  {'S': '[{"F": 50, "L": 50, "O": 50, "W": 50}]'}
# 1551  {'S': '[{"F": 60, "L": 95, "O": 25, "W": 43}]'}
# 1552  {'S': '[{"F": 45, "L": 95, "O": 44, "W": 43}]'}
# 1553  {'S': '[{"F": 17, "L": 95, "O": 88, "W": 79}]'}
# 1554  {'S': '[{"F": 43, "L": 74, "O": 67, "W": 59}]'}
#
#                                    adapted_percentage       compressed  \
# 0     {'S': '[{"F": 37, "L": 86, "O": 41, "W": 65}]'}  {'BOOL': False}
# 1     {'S': '[{"F": 88, "L": 29, "O": 30, "W": 43}]'}  {'BOOL': False}
# 2     {'S': '[{"F": 32, "L": 81, "O": 53, "W": 29}]'}  {'BOOL': False}
# 3     {'S': '[{"F": 69, "L": 75, "O": 20, "W": 43}]'}  {'BOOL': False}
# 4     {'S': '[{"F": 47, "L": 50, "O": 46, "W": 73}]'}  {'BOOL': False}
# ...                                               ...              ...
# 1550  {'S': '[{"F": 50, "L": 50, "O": 50, "W": 50}]'}  {'BOOL': False}
# 1551  {'S': '[{"F": 37, "L": 86, "O": 41, "W": 53}]'}  {'BOOL': False}
# 1552  {'S': '[{"F": 32, "L": 81, "O": 59, "W": 43}]'}  {'BOOL': False}
# 1553  {'S': '[{"F": 25, "L": 67, "O": 72, "W": 73}]'}  {'BOOL': False}
# 1554  {'S': '[{"F": 62, "L": 39, "O": 53, "W": 53}]'}  {'BOOL': False}
#
#             over_time
# 0     {'BOOL': False}
# 1     {'BOOL': False}
# 2     {'BOOL': False}
# 3     {'BOOL': False}
# 4     {'BOOL': False}
# ...               ...
# 1550   {'BOOL': True}
# 1551  {'BOOL': False}
# 1552  {'BOOL': False}
# 1553  {'BOOL': False}
# 1554  {'BOOL': False}
#
# [1555 rows x 6 columns]

# %%
# passa pelo dataframe lendo linha a linha

# for index, row in data.iterrows() :
#     role = eval(row['role'])
#     # print(index, row)
#     print(role)

# %%
# serie = list(data['role'])

# %%
#tratando coluna 'role'

def tratamento_coluna (data: pd.DataFrame, serie:str, get:str) :
    
    series = list(data[serie])
    new_list = list()
    for elem in series :
        new_list.append(eval(elem).get(get))
    data[serie] = new_list

    return data

# %%
data = tratamento_coluna (data=data, serie='role', get='S')

# %%
data
# Out:
#                                 role          fit  \
# 0       Analista de Recursos Humanos  {'N': '77'}
# 1        Diretor de Recursos Humanos  {'N': '51'}
# 2                  Diretor Executivo  {'N': '49'}
# 3        CEO Chief Executive Officer  {'N': '64'}
# 4            Auxiliar Administrativo  {'N': '70'}
# ...                              ...          ...
# 1550            Analista de Sistemas   {'N': '0'}
# 1551  Coordenador de Desenvolvimento  {'N': '44'}
# 1552    Analista de Recursos Humanos  {'N': '74'}
# 1553     Gerente de Recursos Humanos  {'N': '44'}
# 1554    Analista de Recursos Humanos  {'N': '83'}
#
#                                    natural_percentage  \
# 0     {'S': '[{"F": 45, "L": 74, "O": 88, "W": 48}]'}
# 1     {'S': '[{"F": 88, "L": 22, "O": 44, "W": 64}]'}
# 2     {'S': '[{"F": 32, "L": 87, "O": 67, "W": 64}]'}
# 3     {'S': '[{"F": 88, "L": 45, "O": 52, "W": 48}]'}
# 4     {'S': '[{"F": 54, "L": 22, "O": 58, "W": 79}]'}
# ...                                               ...
# 1550  {'S': '[{"F": 50, "L": 50, "O": 50, "W": 50}]'}
# 1551  {'S': '[{"F": 60, "L": 95, "O": 25, "W": 43}]'}
# 1552  {'S': '[{"F": 45, "L": 95, "O": 44, "W": 43}]'}
# 1553  {'S': '[{"F": 17, "L": 95, "O": 88, "W": 79}]'}
# 1554  {'S': '[{"F": 43, "L": 74, "O": 67, "W": 59}]'}
#
#                                    adapted_percentage       compressed  \
# 0     {'S': '[{"F": 37, "L": 86, "O": 41, "W": 65}]'}  {'BOOL': False}
# 1     {'S': '[{"F": 88, "L": 29, "O": 30, "W": 43}]'}  {'BOOL': False}
# 2     {'S': '[{"F": 32, "L": 81, "O": 53, "W": 29}]'}  {'BOOL': False}
# 3     {'S': '[{"F": 69, "L": 75, "O": 20, "W": 43}]'}  {'BOOL': False}
# 4     {'S': '[{"F": 47, "L": 50, "O": 46, "W": 73}]'}  {'BOOL': False}
# ...                                               ...              ...
# 1550  {'S': '[{"F": 50, "L": 50, "O": 50, "W": 50}]'}  {'BOOL': False}
# 1551  {'S': '[{"F": 37, "L": 86, "O": 41, "W": 53}]'}  {'BOOL': False}
# 1552  {'S': '[{"F": 32, "L": 81, "O": 59, "W": 43}]'}  {'BOOL': False}
# 1553  {'S': '[{"F": 25, "L": 67, "O": 72, "W": 73}]'}  {'BOOL': False}
# 1554  {'S': '[{"F": 62, "L": 39, "O": 53, "W": 53}]'}  {'BOOL': False}
#
#             over_time
# 0     {'BOOL': False}
# 1     {'BOOL': False}
# 2     {'BOOL': False}
# 3     {'BOOL': False}
# 4     {'BOOL': False}
# ...               ...
# 1550   {'BOOL': True}
# 1551  {'BOOL': False}
# 1552  {'BOOL': False}
# 1553  {'BOOL': False}
# 1554  {'BOOL': False}
#
# [1555 rows x 6 columns]

# %%
data = tratamento_coluna(data=data, serie='fit', get='N')

# %%
data
# Out:
#                                 role fit  \
# 0       Analista de Recursos Humanos  77
# 1        Diretor de Recursos Humanos  51
# 2                  Diretor Executivo  49
# 3        CEO Chief Executive Officer  64
# 4            Auxiliar Administrativo  70
# ...                              ...  ..
# 1550            Analista de Sistemas   0
# 1551  Coordenador de Desenvolvimento  44
# 1552    Analista de Recursos Humanos  74
# 1553     Gerente de Recursos Humanos  44
# 1554    Analista de Recursos Humanos  83
#
#                                    natural_percentage  \
# 0     {'S': '[{"F": 45, "L": 74, "O": 88, "W": 48}]'}
# 1     {'S': '[{"F": 88, "L": 22, "O": 44, "W": 64}]'}
# 2     {'S': '[{"F": 32, "L": 87, "O": 67, "W": 64}]'}
# 3     {'S': '[{"F": 88, "L": 45, "O": 52, "W": 48}]'}
# 4     {'S': '[{"F": 54, "L": 22, "O": 58, "W": 79}]'}
# ...                                               ...
# 1550  {'S': '[{"F": 50, "L": 50, "O": 50, "W": 50}]'}
# 1551  {'S': '[{"F": 60, "L": 95, "O": 25, "W": 43}]'}
# 1552  {'S': '[{"F": 45, "L": 95, "O": 44, "W": 43}]'}
# 1553  {'S': '[{"F": 17, "L": 95, "O": 88, "W": 79}]'}
# 1554  {'S': '[{"F": 43, "L": 74, "O": 67, "W": 59}]'}
#
#                                    adapted_percentage       compressed  \
# 0     {'S': '[{"F": 37, "L": 86, "O": 41, "W": 65}]'}  {'BOOL': False}
# 1     {'S': '[{"F": 88, "L": 29, "O": 30, "W": 43}]'}  {'BOOL': False}
# 2     {'S': '[{"F": 32, "L": 81, "O": 53, "W": 29}]'}  {'BOOL': False}
# 3     {'S': '[{"F": 69, "L": 75, "O": 20, "W": 43}]'}  {'BOOL': False}
# 4     {'S': '[{"F": 47, "L": 50, "O": 46, "W": 73}]'}  {'BOOL': False}
# ...                                               ...              ...
# 1550  {'S': '[{"F": 50, "L": 50, "O": 50, "W": 50}]'}  {'BOOL': False}
# 1551  {'S': '[{"F": 37, "L": 86, "O": 41, "W": 53}]'}  {'BOOL': False}
# 1552  {'S': '[{"F": 32, "L": 81, "O": 59, "W": 43}]'}  {'BOOL': False}
# 1553  {'S': '[{"F": 25, "L": 67, "O": 72, "W": 73}]'}  {'BOOL': False}
# 1554  {'S': '[{"F": 62, "L": 39, "O": 53, "W": 53}]'}  {'BOOL': False}
#
#             over_time
# 0     {'BOOL': False}
# 1     {'BOOL': False}
# 2     {'BOOL': False}
# 3     {'BOOL': False}
# 4     {'BOOL': False}
# ...               ...
# 1550   {'BOOL': True}
# 1551  {'BOOL': False}
# 1552  {'BOOL': False}
# 1553  {'BOOL': False}
# 1554  {'BOOL': False}
#
# [1555 rows x 6 columns]

# %%
data = tratamento_coluna(data=data, serie='compressed', get='BOOL')

# %%
data
# Out:
#                                 role fit  \
# 0       Analista de Recursos Humanos  77
# 1        Diretor de Recursos Humanos  51
# 2                  Diretor Executivo  49
# 3        CEO Chief Executive Officer  64
# 4            Auxiliar Administrativo  70
# ...                              ...  ..
# 1550            Analista de Sistemas   0
# 1551  Coordenador de Desenvolvimento  44
# 1552    Analista de Recursos Humanos  74
# 1553     Gerente de Recursos Humanos  44
# 1554    Analista de Recursos Humanos  83
#
#                                    natural_percentage  \
# 0     {'S': '[{"F": 45, "L": 74, "O": 88, "W": 48}]'}
# 1     {'S': '[{"F": 88, "L": 22, "O": 44, "W": 64}]'}
# 2     {'S': '[{"F": 32, "L": 87, "O": 67, "W": 64}]'}
# 3     {'S': '[{"F": 88, "L": 45, "O": 52, "W": 48}]'}
# 4     {'S': '[{"F": 54, "L": 22, "O": 58, "W": 79}]'}
# ...                                               ...
# 1550  {'S': '[{"F": 50, "L": 50, "O": 50, "W": 50}]'}
# 1551  {'S': '[{"F": 60, "L": 95, "O": 25, "W": 43}]'}
# 1552  {'S': '[{"F": 45, "L": 95, "O": 44, "W": 43}]'}
# 1553  {'S': '[{"F": 17, "L": 95, "O": 88, "W": 79}]'}
# 1554  {'S': '[{"F": 43, "L": 74, "O": 67, "W": 59}]'}
#
#                                    adapted_percentage  compressed  \
# 0     {'S': '[{"F": 37, "L": 86, "O": 41, "W": 65}]'}       False
# 1     {'S': '[{"F": 88, "L": 29, "O": 30, "W": 43}]'}       False
# 2     {'S': '[{"F": 32, "L": 81, "O": 53, "W": 29}]'}       False
# 3     {'S': '[{"F": 69, "L": 75, "O": 20, "W": 43}]'}       False
# 4     {'S': '[{"F": 47, "L": 50, "O": 46, "W": 73}]'}       False
# ...                                               ...         ...
# 1550  {'S': '[{"F": 50, "L": 50, "O": 50, "W": 50}]'}       False
# 1551  {'S': '[{"F": 37, "L": 86, "O": 41, "W": 53}]'}       False
# 1552  {'S': '[{"F": 32, "L": 81, "O": 59, "W": 43}]'}       False
# 1553  {'S': '[{"F": 25, "L": 67, "O": 72, "W": 73}]'}       False
# 1554  {'S': '[{"F": 62, "L": 39, "O": 53, "W": 53}]'}       False
#
#             over_time
# 0     {'BOOL': False}
# 1     {'BOOL': False}
# 2     {'BOOL': False}
# 3     {'BOOL': False}
# 4     {'BOOL': False}
# ...               ...
# 1550   {'BOOL': True}
# 1551  {'BOOL': False}
# 1552  {'BOOL': False}
# 1553  {'BOOL': False}
# 1554  {'BOOL': False}
#
# [1555 rows x 6 columns]

# %%
data = tratamento_coluna(data=data, serie='over_time', get='BOOL')

# %%
data
# Out:
#                                 role fit  \
# 0       Analista de Recursos Humanos  77
# 1        Diretor de Recursos Humanos  51
# 2                  Diretor Executivo  49
# 3        CEO Chief Executive Officer  64
# 4            Auxiliar Administrativo  70
# ...                              ...  ..
# 1550            Analista de Sistemas   0
# 1551  Coordenador de Desenvolvimento  44
# 1552    Analista de Recursos Humanos  74
# 1553     Gerente de Recursos Humanos  44
# 1554    Analista de Recursos Humanos  83
#
#                                    natural_percentage  \
# 0     {'S': '[{"F": 45, "L": 74, "O": 88, "W": 48}]'}
# 1     {'S': '[{"F": 88, "L": 22, "O": 44, "W": 64}]'}
# 2     {'S': '[{"F": 32, "L": 87, "O": 67, "W": 64}]'}
# 3     {'S': '[{"F": 88, "L": 45, "O": 52, "W": 48}]'}
# 4     {'S': '[{"F": 54, "L": 22, "O": 58, "W": 79}]'}
# ...                                               ...
# 1550  {'S': '[{"F": 50, "L": 50, "O": 50, "W": 50}]'}
# 1551  {'S': '[{"F": 60, "L": 95, "O": 25, "W": 43}]'}
# 1552  {'S': '[{"F": 45, "L": 95, "O": 44, "W": 43}]'}
# 1553  {'S': '[{"F": 17, "L": 95, "O": 88, "W": 79}]'}
# 1554  {'S': '[{"F": 43, "L": 74, "O": 67, "W": 59}]'}
#
#                                    adapted_percentage  compressed  over_time
# 0     {'S': '[{"F": 37, "L": 86, "O": 41, "W": 65}]'}       False      False
# 1     {'S': '[{"F": 88, "L": 29, "O": 30, "W": 43}]'}       False      False
# 2     {'S': '[{"F": 32, "L": 81, "O": 53, "W": 29}]'}       False      False
# 3     {'S': '[{"F": 69, "L": 75, "O": 20, "W": 43}]'}       False      False
# 4     {'S': '[{"F": 47, "L": 50, "O": 46, "W": 73}]'}       False      False
# ...                                               ...         ...        ...
# 1550  {'S': '[{"F": 50, "L": 50, "O": 50, "W": 50}]'}       False       True
# 1551  {'S': '[{"F": 37, "L": 86, "O": 41, "W": 53}]'}       False      False
# 1552  {'S': '[{"F": 32, "L": 81, "O": 59, "W": 43}]'}       False      False
# 1553  {'S': '[{"F": 25, "L": 67, "O": 72, "W": 73}]'}       False      False
# 1554  {'S': '[{"F": 62, "L": 39, "O": 53, "W": 53}]'}       False      False
#
# [1555 rows x 6 columns]

# %%
series = data["natural_percentage"].apply( lambda x: eval(x))

# %%
dic = {
    "F" : [],
    "L" : [],
    "O" : [],
    "W" : []
}
for line in list(series) : 
    list_ = line["S"]
    dict_ = eval(list_)[0]

    for key, values in dict_.items() :
        dic[key].append(values)
    
for key, value in dic.items() :
    data[f"natural_{key.lower()}"] = value

# %%
data
# Out:
#                                 role fit  \
# 0       Analista de Recursos Humanos  77
# 1        Diretor de Recursos Humanos  51
# 2                  Diretor Executivo  49
# 3        CEO Chief Executive Officer  64
# 4            Auxiliar Administrativo  70
# ...                              ...  ..
# 1550            Analista de Sistemas   0
# 1551  Coordenador de Desenvolvimento  44
# 1552    Analista de Recursos Humanos  74
# 1553     Gerente de Recursos Humanos  44
# 1554    Analista de Recursos Humanos  83
#
#                                    natural_percentage  \
# 0     {'S': '[{"F": 45, "L": 74, "O": 88, "W": 48}]'}
# 1     {'S': '[{"F": 88, "L": 22, "O": 44, "W": 64}]'}
# 2     {'S': '[{"F": 32, "L": 87, "O": 67, "W": 64}]'}
# 3     {'S': '[{"F": 88, "L": 45, "O": 52, "W": 48}]'}
# 4     {'S': '[{"F": 54, "L": 22, "O": 58, "W": 79}]'}
# ...                                               ...
# 1550  {'S': '[{"F": 50, "L": 50, "O": 50, "W": 50}]'}
# 1551  {'S': '[{"F": 60, "L": 95, "O": 25, "W": 43}]'}
# 1552  {'S': '[{"F": 45, "L": 95, "O": 44, "W": 43}]'}
# 1553  {'S': '[{"F": 17, "L": 95, "O": 88, "W": 79}]'}
# 1554  {'S': '[{"F": 43, "L": 74, "O": 67, "W": 59}]'}
#
#                                    adapted_percentage  compressed  over_time  \
# 0     {'S': '[{"F": 37, "L": 86, "O": 41, "W": 65}]'}       False      False
# 1     {'S': '[{"F": 88, "L": 29, "O": 30, "W": 43}]'}       False      False
# 2     {'S': '[{"F": 32, "L": 81, "O": 53, "W": 29}]'}       False      False
# 3     {'S': '[{"F": 69, "L": 75, "O": 20, "W": 43}]'}       False      False
# 4     {'S': '[{"F": 47, "L": 50, "O": 46, "W": 73}]'}       False      False
# ...                                               ...         ...        ...
# 1550  {'S': '[{"F": 50, "L": 50, "O": 50, "W": 50}]'}       False       True
# 1551  {'S': '[{"F": 37, "L": 86, "O": 41, "W": 53}]'}       False      False
# 1552  {'S': '[{"F": 32, "L": 81, "O": 59, "W": 43}]'}       False      False
# 1553  {'S': '[{"F": 25, "L": 67, "O": 72, "W": 73}]'}       False      False
# 1554  {'S': '[{"F": 62, "L": 39, "O": 53, "W": 53}]'}       False      False
#
#       natural_f  natural_l  natural_o  natural_w
# 0            45         74         88         48
# 1            88         22         44         64
# 2            32         87         67         64
# 3            88         45         52         48
# 4            54         22         58         79
# ...         ...        ...        ...        ...
# 1550         50         50         50         50
# 1551         60         95         25         43
# 1552         45         95         44         43
# 1553         17         95         88         79
# 1554         43         74         67         59
#
# [1555 rows x 10 columns]

# %%
series = data["adapted_percentage"].apply( lambda x: eval(x))

# %%
dic = {
    "F" : [],
    "L" : [],
    "O" : [],
    "W" : []
}
for line in list(series) : 
    list_ = line["S"]
    dict_ = eval(list_)[0]

    for key, values in dict_.items() :
        dic[key].append(values)
    
for key, value in dic.items() :
    data[f"adapted_{key.lower()}"] = value

# %%
data
# Out:
#                                 role fit  \
# 0       Analista de Recursos Humanos  77
# 1        Diretor de Recursos Humanos  51
# 2                  Diretor Executivo  49
# 3        CEO Chief Executive Officer  64
# 4            Auxiliar Administrativo  70
# ...                              ...  ..
# 1550            Analista de Sistemas   0
# 1551  Coordenador de Desenvolvimento  44
# 1552    Analista de Recursos Humanos  74
# 1553     Gerente de Recursos Humanos  44
# 1554    Analista de Recursos Humanos  83
#
#                                    natural_percentage  \
# 0     {'S': '[{"F": 45, "L": 74, "O": 88, "W": 48}]'}
# 1     {'S': '[{"F": 88, "L": 22, "O": 44, "W": 64}]'}
# 2     {'S': '[{"F": 32, "L": 87, "O": 67, "W": 64}]'}
# 3     {'S': '[{"F": 88, "L": 45, "O": 52, "W": 48}]'}
# 4     {'S': '[{"F": 54, "L": 22, "O": 58, "W": 79}]'}
# ...                                               ...
# 1550  {'S': '[{"F": 50, "L": 50, "O": 50, "W": 50}]'}
# 1551  {'S': '[{"F": 60, "L": 95, "O": 25, "W": 43}]'}
# 1552  {'S': '[{"F": 45, "L": 95, "O": 44, "W": 43}]'}
# 1553  {'S': '[{"F": 17, "L": 95, "O": 88, "W": 79}]'}
# 1554  {'S': '[{"F": 43, "L": 74, "O": 67, "W": 59}]'}
#
#                                    adapted_percentage  compressed  over_time  \
# 0     {'S': '[{"F": 37, "L": 86, "O": 41, "W": 65}]'}       False      False
# 1     {'S': '[{"F": 88, "L": 29, "O": 30, "W": 43}]'}       False      False
# 2     {'S': '[{"F": 32, "L": 81, "O": 53, "W": 29}]'}       False      False
# 3     {'S': '[{"F": 69, "L": 75, "O": 20, "W": 43}]'}       False      False
# 4     {'S': '[{"F": 47, "L": 50, "O": 46, "W": 73}]'}       False      False
# ...                                               ...         ...        ...
# 1550  {'S': '[{"F": 50, "L": 50, "O": 50, "W": 50}]'}       False       True
# 1551  {'S': '[{"F": 37, "L": 86, "O": 41, "W": 53}]'}       False      False
# 1552  {'S': '[{"F": 32, "L": 81, "O": 59, "W": 43}]'}       False      False
# 1553  {'S': '[{"F": 25, "L": 67, "O": 72, "W": 73}]'}       False      False
# 1554  {'S': '[{"F": 62, "L": 39, "O": 53, "W": 53}]'}       False      False
#
#       natural_f  natural_l  natural_o  natural_w  adapted_f  adapted_l  \
# 0            45         74         88         48         37         86
# 1            88         22         44         64         88         29
# 2            32         87         67         64         32         81
# 3            88         45         52         48         69         75
# 4            54         22         58         79         47         50
# ...         ...        ...        ...        ...        ...        ...
# 1550         50         50         50         50         50         50
# 1551         60         95         25         43         37         86
# 1552         45         95         44         43         32         81
# 1553         17         95         88         79         25         67
# 1554         43         74         67         59         62         39
#
#       adapted_o  adapted_w
# 0            41         65
# 1            30         43
# 2            53         29
# 3            20         43
# 4            46         73
# ...         ...        ...
# 1550         50         50
# 1551         41         53
# 1552         59         43
# 1553         72         73
# 1554         53         53
#
# [1555 rows x 14 columns]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
