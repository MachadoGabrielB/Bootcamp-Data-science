# %% [markdown]
# # Calculando Value at Risk (VAR)

# %% [markdown]
# 1.0 - Importando bibliotecas

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %% [markdown]
# 2.0 - Construir a carteira

# %%
ativos = ['ITSA4.SA',
          'PETR4.SA',
          'ABEV3.SA',
          'VALE3.SA'
          ]

# %%
pesos = np.array([0.25,0.25,0.25,0.25])

# %%
carteira = yf.download(ativos, start = '2016-01-01', end = '2020-12-30')['Adj Close']
# Out:
# [*********************100%%**********************]  4 of 4 completed

# %%
carteira.head()
# Out:
#              ABEV3.SA  ITSA4.SA  PETR4.SA  VALE3.SA
# Date
# 2016-01-04  13.508917  2.972659  2.435921  7.997640
# 2016-01-05  13.720852  3.022204  2.368552  7.890500
# 2016-01-06  13.587413  3.049228  2.269271  7.310688
# 2016-01-07  13.226337  3.004187  2.219631  6.875827
# 2016-01-08  13.399025  3.004187  2.223177  6.642643

# %% [markdown]
# 3.0 Análises da carteira

# %%
retornos = carteira.pct_change()
retornos.head()
# Out:
#             ABEV3.SA  ITSA4.SA  PETR4.SA  VALE3.SA
# Date
# 2016-01-04       NaN       NaN       NaN       NaN
# 2016-01-05  0.015689  0.016667 -0.027656 -0.013397
# 2016-01-06 -0.009725  0.008942 -0.041916 -0.073482
# 2016-01-07 -0.026574 -0.014771 -0.021875 -0.059483
# 2016-01-08  0.013056  0.000000  0.001597 -0.033914

# %%
retorno_carteira = (retornos * pesos).sum(axis=1)
retorno_carteira
# Out:
# Date
# 2016-01-04    0.000000
# 2016-01-05   -0.002174
# 2016-01-06   -0.029046
# 2016-01-07   -0.030676
# 2016-01-08   -0.004815
#                 ...
# 2020-12-21   -0.023114
# 2020-12-22    0.004534
# 2020-12-23    0.013108
# 2020-12-28    0.009054
# 2020-12-29    0.004448
# Length: 1244, dtype: float64

# %%
retorno_portfolio = pd.DataFrame()
retorno_portfolio['Retornos'] = retorno_carteira
retorno_portfolio
# Out:
#             Retornos
# Date
# 2016-01-04  0.000000
# 2016-01-05 -0.002174
# 2016-01-06 -0.029046
# 2016-01-07 -0.030676
# 2016-01-08 -0.004815
# ...              ...
# 2020-12-21 -0.023114
# 2020-12-22  0.004534
# 2020-12-23  0.013108
# 2020-12-28  0.009054
# 2020-12-29  0.004448
#
# [1244 rows x 1 columns]

# %%
# Representação gráfica dos retornos

fig = go.Figure()
fig.add_trace(go.Histogram(x=retorno_portfolio['Retornos'], nbinsx=80))
fig.update_layout(title_text= 'Distribuição dos Retornos Carteira', template = 'simple_white')
fig.show()

# %% [markdown]
# 4.0 Value at Risk (VaR) Histórico

# %%
# Existe 5% de chance das perdas diárias excederem o valor de 2,67%

var_95 = np.nanpercentile(retorno_portfolio, 5)
var_95
# Out:
# -0.02670828341321009

# %%
var_98 = np.nanpercentile( retorno_portfolio, 2)
var_98
# Out:
# -0.03814871944410991

# %%
var_99 = np.nanpercentile( retorno_portfolio, 1)
var_99
# Out:
# -0.04811635343008373
