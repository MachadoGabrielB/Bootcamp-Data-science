# %% [markdown]
# Acessando API do governo

# %%
import requests

# %%
url = 'https://dadosabertos.camara.leg.br/api/v2/deputados'

# %%
resposta = requests.get(url)

# %%
resposta.status_code # se der 200 está ok, lembrar do erro 404 NotFound
# Out:
# 200

# %%
resposta.headers
# Out:
# {'Date': 'Thu, 14 Sep 2023 00:24:37 GMT', 'Server': 'Apache', 'Content-Type': 'application/json;charset=UTF-8', 'vary': 'Accept,Accept-Encoding,User-Agent', 'access-control-expose-headers': 'Link, X-Total-Count, X-Validation-Error', 'x-total-count': '513', 'link': '<https://dadosabertos.camara.leg.br/api/v2/deputados>; rel="self",<https://dadosabertos.camara.leg.br/api/v2/deputados?pagina=1&itens=1000>; rel="first",<https://dadosabertos.camara.leg.br/api/v2/deputados?pagina=1&itens=1000>; rel="last",', 'cache-control': 'public, max-age=1800', 'retry-after': '30', 'Content-Encoding': 'gzip', 'Content-Length': '16515', 'Keep-Alive': 'timeout=1, max=5', 'Connection': 'Keep-Alive'}

# %%
resposta.text
# Out:
# '{"dados":[{"id":220593,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/220593","nome":"Abilio Brunini","siglaPartido":"PL","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/37906","siglaUf":"MT","idLegislatura":57,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/220593.jpg","email":"dep.abiliobrunini@camara.leg.br"},{"id":204379,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/204379","nome":"Acácio Favacho","siglaPartido":"MDB","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/36899","siglaUf":"AP","idLegislatura":57,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/204379.jpg","email":"dep.acaciofavacho@camara.leg.br"},{"id":220714,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/220714","nome":"Adail Filho","siglaPartido":"REPUBLICANOS","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/37908","siglaUf":"AM","idLegislatura":57,"urlFoto":"https://www.camara.leg.br/internet/deputado/
# ...

# %%
resposta.json()
# Out:
# {'dados': [{'id': 220593,
#    'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/220593',
#    'nome': 'Abilio Brunini',
#    'siglaPartido': 'PL',
#    'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37906',
#    'siglaUf': 'MT',
#    'idLegislatura': 57,
#    'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/220593.jpg',
#    'email': 'dep.abiliobrunini@camara.leg.br'},
#   {'id': 204379,
#    'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204379',
#    'nome': 'Acácio Favacho',
#    'siglaPartido': 'MDB',
#    'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36899',
#    'siglaUf': 'AP',
#    'idLegislatura': 57,
#    'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204379.jpg',
#    'email': 'dep.acaciofavacho@camara.leg.br'},
#   {'id': 220714,
#    'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/220714',
#    'nome': 'Adail Filho',
#    'siglaPartido': 'REPUBLICANOS',
# ...

# %%
url1 = 'https://dadosabertos.camara.leg.br/api/v2/deputados/137070/despesas'
resposta1 = requests.get(url1)
resposta1.json()
# Out:
# {'dados': [{'ano': 2023,
#    'mes': 4,
#    'tipoDespesa': 'DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.',
#    'codDocumento': 7534099,
#    'tipoDocumento': 'Nota Fiscal',
#    'codTipoDocumento': 0,
#    'dataDocumento': '2023-05-02',
#    'numDocumento': '202300000000004',
#    'valorDocumento': 500.0,
#    'urlDocumento': 'https://www.camara.leg.br/cota-parlamentar/documentos/publ/3059/2023/7534099.pdf',
#    'nomeFornecedor': '49.719.890 QUINTINO DE CASTRO NETO',
#    'cnpjCpfFornecedor': '49719890000185',
#    'valorLiquido': 500.0,
#    'valorGlosa': 0.0,
#    'numRessarcimento': '',
#    'codLote': 1928247,
#    'parcela': 0},
#   {'ano': 2023,
#    'mes': 3,
#    'tipoDespesa': 'DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.',
#    'codDocumento': 7520205,
#    'tipoDocumento': 'Nota Fiscal',
#    'codTipoDocumento': 0,
#    'dataDocumento': '2023-03-28',
#    'numDocumento': '202300000000031',
#    'valorDocumento': 500.0,
# ...

# %%
gastos_vicentinho = resposta1.json()

# %%
gastos_vicentinho['dados'][0]['ano']
# Out:
# 2023
