# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from sklearn.decomposition import PCA
# Out:
# WARNING:tensorflow:From c:\Users\Gabriel-PC\Bootcamp-Data-science\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Função para carregar imagens e pré-processá-las
def load_images(image_paths, target_size=(224, 224)):
    images = []
    for img_path in image_paths:
        img = image.load_img(img_path, target_size=target_size)
        img = image.img_to_array(img)
        img = np.expand_dims(img, axis=0)
        img = preprocess_input(img)
        images.append(img)
    return np.vstack(images)

# %%
# Diretório contendo as imagens
base_dir = r'C:\Users\Gabriel-PC\Bootcamp-Data-science\Personal\10 - Deeplearning\PD\imagens'

# Lista todas as pastas dentro do diretório
pastas = [nome for nome in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, nome))]

# Imprime o nome de todas as pastas
for pasta in pastas:
    print(pasta)
# Out:
# butterfly
# cat
# chicken
# cow
# dogs
# elephant
# horse
# sheep
# spider
# squirrel

# %%
# Carregar as imagens e obter as features da penúltima camada da ResNet50
model = ResNet50(weights='imagenet', include_top=False)
image_files = os.listdir(base_dir)
#image_paths = [os.path.join(base_dir, img) for img in image_files]
# Out:
# WARNING:tensorflow:From c:\Users\Gabriel-PC\Bootcamp-Data-science\.venv\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\Gabriel-PC\Bootcamp-Data-science\.venv\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 4s 0us/step

# %%
for img in image_files:
    path2 = os.path.join(base_dir, img)
    for img2 in os.listdir(path2):
        #print(os.path.join(path2, img2))
        path3 = (os.path.join(path2, img2))

# %%
images = load_images([path3,path3])
#print(images)

# %%
features = model.predict(images)
features_flatten = features.reshape(features.shape[0], -1)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
# Redução de dimensionalidade usando PCA
pca = PCA(n_components=100)
features_pca = pca.fit_transform(features_flatten)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Redução de dimensionalidade usando PCA
#       2 pca = PCA(n_components=100)
# ----> 3 features_pca = pca.fit_transform(features_flatten)
#
# File c:\Users\Gabriel-PC\Bootcamp-Data-science\.venv\lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File c:\Users\Gabriel-PC\Bootcamp-Data-science\.venv\lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Gabriel-PC\Bootcamp-Data-science\.venv\lib\site-packages\sklearn\decomposition\_pca.py:460, in PCA.fit_transform(self, X, y)
#     437 @_fit_context(prefer_skip_nested_validation=True)
#     438 def fit_transform(self, X, y=None):
#     439     """Fit the model with X and apply the dimensionality reduction on X.
#     440
#     441     Parameters
#    (...)
#     458     C-ordered array, use 'np.ascontiguousarray'.
#     459     """
# --> 460     U, S, Vt = self._fit(X)
#     461     U = U[:, : self.n_components_]
#     463     if self.whiten:
#     464         # X_new = X * V / S * sqrt(n_samples) = U * sqrt(n_samples)
#
# File c:\Users\Gabriel-PC\Bootcamp-Data-science\.venv\lib\site-packages\sklearn\decomposition\_pca.py:510, in PCA._fit(self, X)
#     508 # Call different fits for either full or truncated SVD
#     509 if self._fit_svd_solver == "full":
# --> 510     return self._fit_full(X, n_components)
#     511 elif self._fit_svd_solver in ["arpack", "randomized"]:
#     512     return self._fit_truncated(X, n_components, self._fit_svd_solver)
#
# File c:\Users\Gabriel-PC\Bootcamp-Data-science\.venv\lib\site-packages\sklearn\decomposition\_pca.py:524, in PCA._fit_full(self, X, n_components)
#     520         raise ValueError(
#     521             "n_components='mle' is only supported if n_samples >= n_features"
#     522         )
#     523 elif not 0 <= n_components <= min(n_samples, n_features):
# --> 524     raise ValueError(
#     525         "n_components=%r must be between 0 and "
#     526         "min(n_samples, n_features)=%r with "
#     527         "svd_solver='full'" % (n_components, min(n_samples, n_features))
#     528     )
#     530 # Center data
#     531 self.mean_ = np.mean(X, axis=0)
#
# ValueError: n_components=100 must be between 0 and min(n_samples, n_features)=2 with svd_solver='full'

# %%
# Clusterização usando K-means
kmeans = KMeans(n_clusters=10)
kmeans.fit(features_pca)
cluster_labels = kmeans.labels_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 # Clusterização usando K-means
#       2 kmeans = KMeans(n_clusters=10)
# ----> 3 kmeans.fit(features_pca)
#       4 cluster_labels = kmeans.labels_
#
# NameError: name 'features_pca' is not defined

# %%
# Exibir exemplos de imagens para cada cluster
num_examples = 5
fig, axs = plt.subplots(10, num_examples, figsize=(15, 20))

for cluster_id in range(10):
    cluster_indices = np.where(cluster_labels == cluster_id)[0]
    cluster_samples = np.random.choice(cluster_indices, num_examples, replace=False)
    for i, sample_idx in enumerate(cluster_samples):
        img = image.load_img(image_paths[sample_idx], target_size=(224, 224))
        axs[cluster_id, i].imshow(img)
        axs[cluster_id, i].axis('off')
        axs[cluster_id, i].set_title(f'Cluster {cluster_id}')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 6
#       3 fig, axs = plt.subplots(10, num_examples, figsize=(15, 20))
#       5 for cluster_id in range(10):
# ----> 6     cluster_indices = np.where(cluster_labels == cluster_id)[0]
#       7     cluster_samples = np.random.choice(cluster_indices, num_examples, replace=False)
#       8     for i, sample_idx in enumerate(cluster_samples):
#
# NameError: name 'cluster_labels' is not defined

# %% [markdown]
# códigos para usar. Gabriel

# %%
# # importando imagens

# (train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# # normalize pixel values to be between 0 and 1

# train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
# train_labels

# %%
# # verificando imagens

# class_names = ['1', '2', ..., 'n']

# plt.figure(figsize=(10,10))
# for i in range (25):
#     plt.subplot(5,5,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(train_images[i])
#     # The CIFAR labels happen to be arrays,
#     # which is why you need the extra index
#     plt.xlabel(class_names[train_labels[i][0]])
# plt.show()

# %%
import tensorflow.keras as K

# %%
input = load_image_from_kaggle()
model_resnet = K.resnet50(params)
output = model_resnet(input)

# %%
# ####
#        modelo_kmenans = Kmeans(k=params)
#        result = Kmeans(output)
#        metrics (result)
#        xxxxxxx
#        xxxxxxx
#        xxxxxxxx
#        xxxxxxx

#  ###

# %%
# res_netModel = K.applications.ResNet50(include_top=False)

# %%
# model = K.models.Sequential()
# model.add(res_netModel)
# model.add(K.layers.Flatten())

# %%
# res_netModel = K.applications.ResNet50(include_top=False)

# %%
# res_netModel.summary()

# %%
# model = K.models.Sequential()
# model.add(res_netModel)
# model.add(K.layers.Flatten())

# %%
# model.summary()

# %%
# output = [ 1a linha - 2048 valores - representa a extracao de característica da 1a imagem
#             2a linha - 2048 valores - representa a extracao de característica da 2a imagem]

# %%
# model = models.Sequential()
# model.add(layers.Conv2D(32, (3, 3), activation= 'relu', input_shape=(32, 32, 3)))
# model.add(layers.MaxPooling2D((2,2)))
# model.add(layers.Conv2D(64, (3, 3), activation= 'relu'))
# model.add(layers.MaxPooling2D((2,2)))
# model.add(layers.Conv2D(64, (3, 3), activation= 'relu'))

# %%
# model.summary()

# %%
# model.add(layers.Flatten())
# model.add(layers.Dense(64, activation= 'relu'))
# model.add(layers.Dense(10))

# %%
# model.summary()

# %%
# tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir= "logs")
# es_callback = tf.keras.callbacks. EarlyStopping(monitor= 'val_loss',
#                                                  min_delta = 0,
#                                                  restore_best_weights = True,
#                                                  patience= 10)

# %%
# model.compile(optimizer= 'adam',
#               loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits= True),
#               metrics=['accuracy'])

# history = model.fit(train_images,
#                     train_labels,
#                     epochs= 300,
#                     validation_data= (test_images, test_labels),
#                     callbacks= [tensorboard_callback, es_callback])

# %%
# # carregar as imagens e obter as features da penúltima camada da ResNet50

# model = ResNet50(weights= 'imagenet',
#                  include_top= False)
# image_files = os.listdir(base_dir)
# image_paths = [os.path.join(base_dir, img) for img in image_files]
# images = load_images(image_paths)
# features = model.predict(images)
# features_flatten = features.reshape

# %%
# import tensorflow.keras as K
